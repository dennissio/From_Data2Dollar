# %%
#import library
import pandas as pd
#read information into Dataframe
airbnb_data = pd.read_csv('airbnb_data.csv')
booking_data = pd.read_excel('ScrapingBooking.xlsx')
print(airbnb_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117734 entries, 0 to 117733
# Data columns (total 10 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date_crawl  117734 non-null  object
#  1   link        112007 non-null  object
#  2   title       112007 non-null  object
#  3   price       103601 non-null  object
#  4   rating      96130 non-null   object
#  5   provider    107083 non-null  object
#  6   ort         112007 non-null  object
#  7   start_buch  112007 non-null  object
#  8   end_buch    112007 non-null  object
#  9   event       112007 non-null  object
# dtypes: object(10)
# memory usage: 9.0+ MB
# None

# %% [markdown]
# Bearbeitung von AirBnB Datensatz

# %%
#Vorbereitung AirBnB Datensatz
airbnb_clean = airbnb_data.drop(['end_buch', 'title'], axis=1)
airbnb_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117734 entries, 0 to 117733
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date_crawl  117734 non-null  object
#  1   link        112007 non-null  object
#  2   price       103601 non-null  object
#  3   rating      96130 non-null   object
#  4   provider    107083 non-null  object
#  5   ort         112007 non-null  object
#  6   start_buch  112007 non-null  object
#  7   event       112007 non-null  object
# dtypes: object(8)
# memory usage: 7.2+ MB

# %%
#anpassung der Spaltennamen
airbnb_clean = airbnb_clean.iloc[:, [0,5,1,6,2,7,3,4]]
airbnb_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117734 entries, 0 to 117733
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date_crawl  117734 non-null  object
#  1   ort         112007 non-null  object
#  2   link        112007 non-null  object
#  3   start_buch  112007 non-null  object
#  4   price       103601 non-null  object
#  5   event       112007 non-null  object
#  6   rating      96130 non-null   object
#  7   provider    107083 non-null  object
# dtypes: object(8)
# memory usage: 7.2+ MB

# %%
#spaltennamen anpassen
airbnb_clean = airbnb_clean.rename(index=str, columns={'date_crawl':'date_crawl' , 'ort':'city', 'link':'uid', 'start_buch':'book_date', 'price':'price', 'event':'event', 'rating':'rating', 'provider':'provider'})
airbnb_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 117734 entries, 0 to 117733
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date_crawl  117734 non-null  object
#  1   city        112007 non-null  object
#  2   uid         112007 non-null  object
#  3   book_date   112007 non-null  object
#  4   price       103601 non-null  object
#  5   event       112007 non-null  object
#  6   rating      96130 non-null   object
#  7   provider    107083 non-null  object
# dtypes: object(8)
# memory usage: 8.1+ MB

# %%
#Anpassung Rating
rating = airbnb_clean['rating'].str.split(' ', expand=True)
airbnb_clean['rating'] = rating[0]
airbnb_clean.head()
# Out:
#    date_crawl      city                       uid   book_date     price event  \
# 0  2023-03-30  La Palma            title_44546103  2023-05-20   90 CHF     ja
# 1  2023-03-30  La Palma            title_14832235  2023-05-20   86 CHF     ja
# 2  2023-03-30  La Palma            title_22183776  2023-05-20   63 CHF     ja
# 3  2023-03-30  La Palma            title_26944967  2023-05-20  109 CHF     ja
# 4  2023-03-30  La Palma  title_741718109680848267  2023-05-20   46 CHF     ja
#
#   rating                provider
# 0   4.78  Private:r Gastgeber:in
# 1   4.78  Private:r Gastgeber:in
# 2    4.9  Private:r Gastgeber:in
# 3   4.76  Private:r Gastgeber:in
# 4   4.85  Private:r Gastgeber:in

# %%
#Anpassung Preis
price = airbnb_clean['price'].str.split('\xa0', expand=True)
airbnb_clean['price'] = price[0]
airbnb_clean.head()
# Out:
#    date_crawl      city                       uid   book_date price event  \
# 0  2023-03-30  La Palma            title_44546103  2023-05-20    90    ja
# 1  2023-03-30  La Palma            title_14832235  2023-05-20    86    ja
# 2  2023-03-30  La Palma            title_22183776  2023-05-20    63    ja
# 3  2023-03-30  La Palma            title_26944967  2023-05-20   109    ja
# 4  2023-03-30  La Palma  title_741718109680848267  2023-05-20    46    ja
#
#   rating                provider
# 0   4.78  Private:r Gastgeber:in
# 1   4.78  Private:r Gastgeber:in
# 2    4.9  Private:r Gastgeber:in
# 3   4.76  Private:r Gastgeber:in
# 4   4.85  Private:r Gastgeber:in

# %%
#Umbenennung Werte
airbnb_clean['provider'] = airbnb_clean['provider'].str.replace('Private:r Gastgeber:in', 'privat')
airbnb_clean['provider'] = airbnb_clean['provider'].str.replace('Gewerbliche:r Vermieter:in', 'gewerblich')
airbnb_clean['event'] = airbnb_clean['event'].str.replace('ja', 'True')
airbnb_clean['event'] = airbnb_clean['event'].str.replace('nein', 'False')
airbnb_clean['rating'] = airbnb_clean['rating'].str.replace('NaN', '')
airbnb_clean['price'] = airbnb_clean['price'].str.replace('NaN', '')
airbnb_clean['rating'] = airbnb_clean['rating'].str.replace('Neu', '')
airbnb_clean['price'] = airbnb_clean['price'].str.replace("’", '')
airbnb_clean
# Out:
#         date_crawl      city                       uid   book_date price  \
# 0       2023-03-30  La Palma            title_44546103  2023-05-20    90
# 1       2023-03-30  La Palma            title_14832235  2023-05-20    86
# 2       2023-03-30  La Palma            title_22183776  2023-05-20    63
# 3       2023-03-30  La Palma            title_26944967  2023-05-20   109
# 4       2023-03-30  La Palma  title_741718109680848267  2023-05-20    46
# ...            ...       ...                       ...         ...   ...
# 117729  2023-04-15     Halle            title_50606410  2023-06-23   117
# 117730  2023-04-15     Halle  title_706133116352835657  2023-06-23   128
# 117731  2023-04-15     Halle            title_50864397  2023-06-23   175
# 117732  2023-04-15     Halle  title_691109319858120657  2023-06-23   157
# 117733  2023-04-15     Halle            title_50606325  2023-06-23   128
#
#         event rating    provider
# 0        True   4.78      privat
# 1        True   4.78      privat
# 2        True    4.9      privat
# 3        True   4.76      privat
# 4        True   4.85      privat
# ...       ...    ...         ...
# 117729  False    NaN  gewerblich
# 117730  False    NaN  gewerblich
# 117731  False    NaN  gewerblich
# 117732  False    NaN  gewerblich
# 117733  False    NaN  gewerblich
#
# [117734 rows x 8 columns]

# %%
#Analyse der fehlenden Daten
airbnb_clean.isnull().sum()
# Out:
# date_crawl        0
# city           5727
# uid            5727
# book_date      5727
# price         14133
# event          5727
# rating        21604
# provider      10651
# dtype: int64

# %%
#Löschen der fehlenden Daten
airbnb_clean_nonull = airbnb_clean.drop(airbnb_clean[airbnb_clean['city'].isnull() == True].index)
airbnb_clean_nonull
# Out:
#         date_crawl      city                       uid   book_date price  \
# 0       2023-03-30  La Palma            title_44546103  2023-05-20    90
# 1       2023-03-30  La Palma            title_14832235  2023-05-20    86
# 2       2023-03-30  La Palma            title_22183776  2023-05-20    63
# 3       2023-03-30  La Palma            title_26944967  2023-05-20   109
# 4       2023-03-30  La Palma  title_741718109680848267  2023-05-20    46
# ...            ...       ...                       ...         ...   ...
# 117729  2023-04-15     Halle            title_50606410  2023-06-23   117
# 117730  2023-04-15     Halle  title_706133116352835657  2023-06-23   128
# 117731  2023-04-15     Halle            title_50864397  2023-06-23   175
# 117732  2023-04-15     Halle  title_691109319858120657  2023-06-23   157
# 117733  2023-04-15     Halle            title_50606325  2023-06-23   128
#
#         event rating    provider
# 0        True   4.78      privat
# 1        True   4.78      privat
# 2        True    4.9      privat
# 3        True   4.76      privat
# 4        True   4.85      privat
# ...       ...    ...         ...
# 117729  False    NaN  gewerblich
# 117730  False    NaN  gewerblich
# 117731  False    NaN  gewerblich
# 117732  False    NaN  gewerblich
# 117733  False    NaN  gewerblich
#
# [112007 rows x 8 columns]

# %%
#Analyse der fehlenden Daten
airbnb_clean_nonull.isnull().sum()
# Out:
# date_crawl        0
# city              0
# uid               0
# book_date         0
# price          8406
# event             0
# rating        15877
# provider       4924
# dtype: int64

# %%
#Löschen der fehlenden Daten
airbnb_clean_nonull = airbnb_clean_nonull.drop(airbnb_clean_nonull[airbnb_clean_nonull['provider'].isnull() == True].index)
airbnb_clean_nonull.isnull().sum()
# Out:
# date_crawl        0
# city              0
# uid               0
# book_date         0
# price          7829
# event             0
# rating        14706
# provider          0
# dtype: int64

# %%
#Änderung Datentypen
airbnb_clean_nonull['date_crawl'] = airbnb_clean_nonull['date_crawl'].astype('datetime64[ns]')
airbnb_clean_nonull['book_date'] = airbnb_clean_nonull['book_date'].astype('datetime64[ns]')
airbnb_clean_nonull['price'] = pd.to_numeric(airbnb_clean_nonull['price'])
airbnb_clean_nonull['rating'] = pd.to_numeric(airbnb_clean_nonull['rating'])
airbnb_clean_nonull['event'] = airbnb_clean_nonull['event'].astype('bool')
airbnb_clean_nonull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 107083 entries, 0 to 117733
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date_crawl  107083 non-null  datetime64[ns]
#  1   city        107083 non-null  object
#  2   uid         107083 non-null  object
#  3   book_date   107083 non-null  datetime64[ns]
#  4   price       99254 non-null   float64
#  5   event       107083 non-null  bool
#  6   rating      79586 non-null   float64
#  7   provider    107083 non-null  object
# dtypes: bool(1), datetime64[ns](2), float64(2), object(3)
# memory usage: 6.6+ MB

# %%
#Anpassung der fehlenden Daten
airbnb_clean_copy = airbnb_clean_nonull
airbnb_clean_copy['rating'] = airbnb_clean_copy['rating'].fillna(airbnb_clean_copy['rating'].mean())
airbnb_clean_copy['price'] = airbnb_clean_copy['price'].fillna(airbnb_clean_copy['price'].mean())
airbnb_clean_nonull['price'] = airbnb_clean_nonull['price'].astype('int')
airbnb_clean_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 107083 entries, 0 to 117733
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date_crawl  107083 non-null  datetime64[ns]
#  1   city        107083 non-null  object
#  2   uid         107083 non-null  object
#  3   book_date   107083 non-null  datetime64[ns]
#  4   price       107083 non-null  int64
#  5   event       107083 non-null  bool
#  6   rating      107083 non-null  float64
#  7   provider    107083 non-null  object
# dtypes: bool(1), datetime64[ns](2), float64(1), int64(1), object(3)
# memory usage: 6.6+ MB

# %% [markdown]
# Bearbeitung von Booking Datensatz

# %%
print(booking_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97491 entries, 0 to 97490
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Stadt          97491 non-null  object
#  1   Datum scraped  97491 non-null  object
#  2   Name           97491 non-null  object
#  3   Preis          97491 non-null  int64
#  4   Event Ja/Nein  97491 non-null  object
#  5   Datum          97491 non-null  object
#  6   Bewertung      94049 non-null  object
#  7   Anbieter       97491 non-null  object
#  8   Link           97491 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 6.7+ MB
# None

# %%
#Entfernung irrelevanter Daten
booking_clean = booking_data.drop('Name', axis=1)
booking_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97491 entries, 0 to 97490
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Stadt          97491 non-null  object
#  1   Datum scraped  97491 non-null  object
#  2   Preis          97491 non-null  int64
#  3   Event Ja/Nein  97491 non-null  object
#  4   Datum          97491 non-null  object
#  5   Bewertung      94049 non-null  object
#  6   Anbieter       97491 non-null  object
#  7   Link           97491 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 6.0+ MB

# %%
#Anpassung der Spalten
booking_clean = booking_clean.iloc[:, [1,0,7,4,2,3,5,6]]
booking_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97491 entries, 0 to 97490
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Datum scraped  97491 non-null  object
#  1   Stadt          97491 non-null  object
#  2   Link           97491 non-null  object
#  3   Datum          97491 non-null  object
#  4   Preis          97491 non-null  int64
#  5   Event Ja/Nein  97491 non-null  object
#  6   Bewertung      94049 non-null  object
#  7   Anbieter       97491 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 6.0+ MB

# %%
#Anpassung der Spaltennamen
booking_clean = booking_clean.rename(index=str, columns={'Datum scraped':'date_crawl' , 'Stadt':'city', 'Link':'uid', 'Datum':'book_date', 'Preis':'price', 'Event Ja/Nein':'event', 'Bewertung':'rating', 'Anbieter':'provider'})
booking_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 97491 entries, 0 to 97490
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date_crawl  97491 non-null  object
#  1   city        97491 non-null  object
#  2   uid         97491 non-null  object
#  3   book_date   97491 non-null  object
#  4   price       97491 non-null  int64
#  5   event       97491 non-null  object
#  6   rating      94049 non-null  object
#  7   provider    97491 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 6.7+ MB

# %%
#Anpassung der Werte
booking_clean['rating'] = booking_clean['rating'].str.replace(',', '.')
booking_clean['rating'] = pd.to_numeric(booking_clean['rating'])
booking_clean
# Out:
#        date_crawl      city  \
# 0      29.03.2023  La Palma
# 1      29.03.2023  La Palma
# 2      29.03.2023  La Palma
# 3      29.03.2023  La Palma
# 4      29.03.2023  La Palma
# ...           ...       ...
# 97486  15.04.2023     Halle
# 97487  15.04.2023     Halle
# 97488  15.04.2023     Halle
# 97489  15.04.2023     Halle
# 97490  15.04.2023     Halle
#
#                                                      uid   book_date  price  \
# 0      https://www.booking.com/hotel/es/cataloniamajo...  20.05.2023    166
# 1      https://www.booking.com/hotel/es/almudaina.de....  20.05.2023    264
# 2      https://www.booking.com/hotel/es/saratoga.de.h...  20.05.2023    348
# 3      https://www.booking.com/hotel/es/hmhotelsjaime...  20.05.2023    314
# 4      https://www.booking.com/hotel/es/ciutat-jardi....  20.05.2023    266
# ...                                                  ...         ...    ...
# 97486  https://www.booking.com/hotel/us/augusta-281-c...  23.06.2023    201
# 97487  https://www.booking.com/hotel/us/little-landin...  23.06.2023      4
# 97488  https://www.booking.com/hotel/us/skyview-treeh...  23.06.2023      2
# 97489  https://www.booking.com/hotel/us/charming-wate...  23.06.2023    767
# 97490  https://www.booking.com/hotel/us/clary-lake-be...  23.06.2023    101
#
#       event  rating    provider
# 0        Ja     8.0  gewerblich
# 1        Ja     8.7  gewerblich
# 2        Ja     8.6  gewerblich
# 3        Ja     8.0  gewerblich
# 4        Ja     8.4  gewerblich
# ...     ...     ...         ...
# 97486  Nein     7.0  gewerblich
# 97487  Nein     NaN      privat
# 97488  Nein     NaN      privat
# 97489  Nein     NaN      privat
# 97490  Nein     9.4  gewerblich
#
# [97491 rows x 8 columns]

# %%
#Anpassung der Werte
booking_clean['rating'] = booking_clean['rating']/2
booking_clean['rating'] = booking_clean['rating'].round(2)
booking_clean
# Out:
#        date_crawl      city  \
# 0      29.03.2023  La Palma
# 1      29.03.2023  La Palma
# 2      29.03.2023  La Palma
# 3      29.03.2023  La Palma
# 4      29.03.2023  La Palma
# ...           ...       ...
# 97486  15.04.2023     Halle
# 97487  15.04.2023     Halle
# 97488  15.04.2023     Halle
# 97489  15.04.2023     Halle
# 97490  15.04.2023     Halle
#
#                                                      uid   book_date  price  \
# 0      https://www.booking.com/hotel/es/cataloniamajo...  20.05.2023    166
# 1      https://www.booking.com/hotel/es/almudaina.de....  20.05.2023    264
# 2      https://www.booking.com/hotel/es/saratoga.de.h...  20.05.2023    348
# 3      https://www.booking.com/hotel/es/hmhotelsjaime...  20.05.2023    314
# 4      https://www.booking.com/hotel/es/ciutat-jardi....  20.05.2023    266
# ...                                                  ...         ...    ...
# 97486  https://www.booking.com/hotel/us/augusta-281-c...  23.06.2023    201
# 97487  https://www.booking.com/hotel/us/little-landin...  23.06.2023      4
# 97488  https://www.booking.com/hotel/us/skyview-treeh...  23.06.2023      2
# 97489  https://www.booking.com/hotel/us/charming-wate...  23.06.2023    767
# 97490  https://www.booking.com/hotel/us/clary-lake-be...  23.06.2023    101
#
#       event  rating    provider
# 0        Ja    4.00  gewerblich
# 1        Ja    4.35  gewerblich
# 2        Ja    4.30  gewerblich
# 3        Ja    4.00  gewerblich
# 4        Ja    4.20  gewerblich
# ...     ...     ...         ...
# 97486  Nein    3.50  gewerblich
# 97487  Nein     NaN      privat
# 97488  Nein     NaN      privat
# 97489  Nein     NaN      privat
# 97490  Nein    4.70  gewerblich
#
# [97491 rows x 8 columns]

# %%
#Analyse der fehlenden Daten
booking_clean.isnull().sum()
# Out:
# date_crawl       0
# city             0
# uid              0
# book_date        0
# price            0
# event            0
# rating        4302
# provider         0
# dtype: int64

# %%
booking_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 97491 entries, 0 to 97490
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date_crawl  97491 non-null  object
#  1   city        97491 non-null  object
#  2   uid         97491 non-null  object
#  3   book_date   97491 non-null  object
#  4   price       97491 non-null  int64
#  5   event       97491 non-null  object
#  6   rating      93189 non-null  float64
#  7   provider    97491 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 6.7+ MB

# %%
#Anpassung der Datentypen
booking_clean['date_crawl'] = booking_clean['date_crawl'].astype('datetime64[ns]')
booking_clean['book_date'] = booking_clean['book_date'].astype('datetime64[ns]')
booking_clean['event'] = booking_clean['event'].str.replace('ja', 'True')
booking_clean['event'] = booking_clean['event'].str.replace('nein', 'False')
booking_clean['event'] = booking_clean['event'].astype('bool')
booking_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 97491 entries, 0 to 97490
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date_crawl  97491 non-null  datetime64[ns]
#  1   city        97491 non-null  object
#  2   uid         97491 non-null  object
#  3   book_date   97491 non-null  datetime64[ns]
#  4   price       97491 non-null  int64
#  5   event       97491 non-null  bool
#  6   rating      93189 non-null  float64
#  7   provider    97491 non-null  object
# dtypes: bool(1), datetime64[ns](2), float64(1), int64(1), object(3)
# memory usage: 6.0+ MB
# /var/folders/sf/yl77jkwn5h97cbf1hh4296g80000gn/T/ipykernel_22382/921434595.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   booking_clean['date_crawl'] = booking_clean['date_crawl'].astype('datetime64[ns]')
# /var/folders/sf/yl77jkwn5h97cbf1hh4296g80000gn/T/ipykernel_22382/921434595.py:3: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   booking_clean['book_date'] = booking_clean['book_date'].astype('datetime64[ns]')

# %%
#Ergaenzung der fehlenden Daten
booking_clean_copy = booking_clean
booking_clean_copy['rating'] = booking_clean_copy['rating'].fillna(booking_clean_copy['rating'].mean())
booking_clean_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 97491 entries, 0 to 97490
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date_crawl  97491 non-null  datetime64[ns]
#  1   city        97491 non-null  object
#  2   uid         97491 non-null  object
#  3   book_date   97491 non-null  datetime64[ns]
#  4   price       97491 non-null  int64
#  5   event       97491 non-null  bool
#  6   rating      97491 non-null  float64
#  7   provider    97491 non-null  object
# dtypes: bool(1), datetime64[ns](2), float64(1), int64(1), object(3)
# memory usage: 6.0+ MB

# %% [markdown]
# Merge Data into one dataset

# %%
#Zusammenfuehrung der Datensaetze
dataframes = [airbnb_clean_copy,booking_clean_copy]
dataset = pd.concat(dataframes)
dataset['city'] = dataset['city'].str.replace('Br√ºssel', 'Bruessel')
dataset['city'] = dataset['city'].str.replace('M√ºnchen', 'Muenchen')
dataset['city'] = dataset['city'].str.replace('Monaco-City', 'Monaco')
#drop unrealistische Preise
dataset.drop(dataset[dataset['price'] <= 20].index, inplace = True)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 202924 entries, 0 to 97490
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date_crawl  202924 non-null  datetime64[ns]
#  1   city        202924 non-null  object
#  2   uid         202924 non-null  object
#  3   book_date   202924 non-null  datetime64[ns]
#  4   price       202924 non-null  int64
#  5   event       202924 non-null  bool
#  6   rating      202924 non-null  float64
#  7   provider    202924 non-null  object
# dtypes: bool(1), datetime64[ns](2), float64(1), int64(1), object(3)
# memory usage: 12.6+ MB

# %%
#Export der Daten
dataset.to_excel('merged_dataset.xlsx')
